# %% [markdown]
# # VA 2021-2022 sem-2 Inleveropdracht 3

# %% [markdown]
# Vul je naam in:

# %% [markdown]
# ## Deadline

# %% [markdown]
# De deadline voor deze opdracht is: 18 maart 18:00

# %% [markdown]
# # Deel 1 - Introductie Folium

# %% [markdown]
# ## Onderdeel 1

# %% [markdown]
# We gaan een kaart maken met behulp van `folium`. Folium is een library die gebruikt wordt voor het visualiseren van geospatiale gegevens. Het is eenvoudig te gebruiken en toch een krachtige library. Informatie over folium kan je bijv. vinden op https://python-visualization.github.io/folium/modules.html. Hieronder is al een voorbeeld gemaakt. De locatie Utrecht centrum is weergegeven als een marker. De onderstaande code produceert een kaart (inclusief een marker), maar is nog niet compleet. Voldoe aan de volgende eisen:
#
# - Gebruik een functie om Nederland direct volledig in beeld te krijgen.
# - Kies zelf nog twee locaties in Nederland en geef de locaties als markers weer met de bijbehorende popup.
# - Pas de code aan en maak de popup tekst dikgedrukt.

# %%
import folium

# Wanneer je een error krijgt, installeer dan folium:
#!pip install folium

# %%
#We hebben zoom_start toegevoegd om nederland volledig in beeld te krijgen
m = folium.Map(location=[52.0893191, 5.1101691], zoom_start=7)

html_utrecht = '''<b>Utrecht</b>'''
html_amsterdam = '''<b>Amsterdam</b>'''
html_schoorl = '''<b>Schoorl</b>'''

iframe_utrecht = folium.IFrame(html_utrecht,
                       width=100,
                       height=100)
popup_utrecht = folium.Popup(iframe_utrecht,
                     max_width=100)
marker_utrecht = folium.Marker([52.0893191, 5.1101691],
                       popup=popup_utrecht).add_to(m)

iframe_amsterdam = folium.IFrame(html_amsterdam,
                       width=100,
                       height=100)
popup_amsterdam = folium.Popup(iframe_amsterdam,
                     max_width=100)
marker_amsterdam = folium.Marker([52.377956, 4.897070],
                       popup=popup_amsterdam).add_to(m)

iframe_schoorl = folium.IFrame(html_schoorl,
                       width=100,
                       height=100)
popup_schoorl = folium.Popup(iframe_schoorl,
                     max_width=100)
marker_schoorl = folium.Marker([52.7054779, 4.7053146],
                       popup=popup_schoorl).add_to(m)

#folium.Marker(location=[52.0893191, 5.1101691],popup='Utrecht centrum',tooltip='Klik hier om de popup te zien').add_to(m)
#folium.Marker(location=[52.377956, 4.897070],popup='Amsterdam centrum',tooltip='Klik hier om de popup te zien').add_to(m)
#folium.Marker(location=[52.7054779, 4.7053146],popup='Schoorl centrum',tooltip='Klik hier om de popup te zien').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## Onderdeel 2

# %% [markdown]
# We gaan nu meerdere kaartlagen toevoegen. De standaard kaartlaag is van openstreetmap.
#
# Kopieer de code uit onderdeel 1 en vul de code aan. Zoek op google naar een alternatieve kaartlaag naar jouw smaak zonder kleur en stel hem in als de standaard kaartlaag. Je zou deze site http://leaflet-extras.github.io/leaflet-providers/preview/ kunnen gebruiken (informatie over tiles kan je vinden op https://python-visualization.github.io/folium/modules.html). Voeg nog drie unieke kaartlagen en een layer control toe, zodat je in de kaart omgeving de kaartlaag kan selecteren. Zorg dat één van je kaartlagen geen kleur heeft.

# %%
folium.TileLayer('stamenwatercolor').add_to(m)
folium.TileLayer('stamentoner').add_to(m)
folium.TileLayer('stamenterrain').add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# # Deel 2 - NO2 metingen

# %% [markdown]
# Voor dit deel gaan we kijken naar NO2 metingen in Amsterdam. We hebben de dataset NO2. Deze dataset bevat metingen van NO2 op verschillende locaties vanaf 2010 t/m 2019.

# %%
import pandas as pd

NO2 = pd.read_csv('NO2_JAREN.csv', sep=";", decimal=',')

NO2.head()
# Out:
#    OBJECTNUMMER    Code               Locatie Type_meetpunt Type_meting  \
# 0             1   IJB19         Ijsbaanpad 19   Achtergrond      Palmes
# 1             2  DECL40    de Clercqstraat 40        Straat      Palmes
# 2             3  SPD165  Spaarndammerdijk 165        Straat      Palmes
# 3             4   SPD53   Spaarndammerdijk 53        Straat      Palmes
# 4             5   SPD29   Spaarndammerdijk 29        Straat      Palmes
#
#   Meting_op_wettelijke_toetsafst  Afstand_tot_gevel_m  jaar_2020  jaar_2019  \
# 0                            NaN                  0.0          0       25.9
# 1                            Nee                  0.0          0       31.6
# 2                             Ja                  0.0          0       32.4
# 3                             Ja                  0.0          0       30.7
# 4                             Ja                  0.0          0       31.5
#
#    jaar_2018  jaar_2017  jaar_2016  jaar_2015  jaar_2014  jaar_2013  \
# ...

# %%
NO2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTNUMMER                    142 non-null    int64
#  1   Code                            142 non-null    object
#  2   Locatie                         142 non-null    object
#  3   Type_meetpunt                   142 non-null    object
#  4   Type_meting                     142 non-null    object
#  5   Meting_op_wettelijke_toetsafst  83 non-null     object
#  6   Afstand_tot_gevel_m             142 non-null    float64
#  7   jaar_2020                       142 non-null    int64
#  8   jaar_2019                       142 non-null    float64
#  9   jaar_2018                       142 non-null    float64
#  10  jaar_2017                       142 non-null    float64
#  11  jaar_2016                       142 non-null    float64
# ...

# %%
NO2.describe()
# Out:
#        OBJECTNUMMER  Afstand_tot_gevel_m  jaar_2020   jaar_2019   jaar_2018  \
# count    142.000000           142.000000      142.0  142.000000  142.000000
# mean      71.500000             2.568310        0.0   27.989437   28.030986
# std       41.135953             5.012741        0.0    9.551798   13.125154
# min        1.000000             0.000000        0.0    0.000000    0.000000
# 25%       36.250000             0.000000        0.0   23.750000   23.750000
# 50%       71.500000             0.000000        0.0   28.800000   29.950000
# 75%      106.750000             3.900000        0.0   33.450000   35.600000
# max      142.000000            31.300000        0.0   45.900000   51.500000
#
#         jaar_2017   jaar_2016   jaar_2015   jaar_2014   jaar_2013   jaar_2012  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    30.529577   26.921831   23.666197   24.446479   24.207042   24.594366
# ...

# %% [markdown]
# ## Onderdeel 3

# %% [markdown]
# In deze opdracht gaan we toewerken naar het verwerken van de data van de NO2-metingen op de kaart. De data willen we graag in kleur. Hiervoor gaan we een geschikt kleurenpalet samenstellen. Defineer een functie `color_producer` die voor elke type meetpunt, een kleur toewijst. Er is hieronder al een begin gemaakt. Je kunt de site https://matplotlib.org/3.1.0/gallery/color/named_colors.html gebruiken voor de verschillende kleurnamen. Bij het uitvoeren van de functie color_producer(NO2.Type_meetpunt[0]), komt daar een kleurnaam uit.

# %%
print(NO2.Type_meetpunt.unique())
# Out:
# ['Achtergrond' 'Straat' 'Snelweg' 'Waterweg' 'Meetstation']

# %%
def color_producer(type):
    if type == 'Achtergrond' :
        return 'blue'
    elif type == 'Straat' :
        return 'red'
    elif type == 'Snelweg' :
        return 'purple'
    elif type == 'Waterweg' :
        return 'yellow'
    elif type == 'Meetstation' :
        return 'green'

# %%
# Hieruit zou een kleurnaam moeten komen
color_producer(NO2.Type_meetpunt[0])
# Out:
# 'blue'

# %% [markdown]
# ## Onderdeel 4

# %% [markdown]
# Maak nu een kaart van NO2 metingen in Amsterdam met de volgende eisen:
#
# - De kaartlaag is zelf niet in kleur.
# - De locaties (een regel in het dataframe) worden door cirkelvormige markeringen weergegeven.
# - Als je in de kaart op een meetpunt klikt wordt het adres zichtbaar
# - De kleur van het weergegeven meetpunt wordt bepaald door de functie color_producer() afhankelijk van de variabele Type_meetpunt.
# - Je plaatst een legenda met correcte titel en labels, je gebruikt immers kleuren die een uitleg nodig hebben.

# %%
#  ik heb een functie gevonden op het internet voor het toevoegen van een categorische legenda:
# (bron: https://stackoverflow.com/questions/65042654/how-to-add-categorical-legend-to-python-folium-map)

def add_categorical_legend(folium_map, title, colors, labels):
    if len(colors) != len(labels):
        raise ValueError("colors and labels must have the same length.")

    color_by_label = dict(zip(labels, colors))
    
    legend_categories = ""     
    for label, color in color_by_label.items():
        legend_categories += f"<li><span style='background:{color}'></span>{label}</li>"
        
    legend_html = f"""
    <div id='maplegend' class='maplegend'>
      <div class='legend-title'>{title}</div>
      <div class='legend-scale'>
        <ul class='legend-labels'>
        {legend_categories}
        </ul>
      </div>
    </div>
    """
    script = f"""
        <script type="text/javascript">
        var oneTimeExecution = (function() {{
                    var executed = false;
                    return function() {{
                        if (!executed) {{
                             var checkExist = setInterval(function() {{
                                       if ((document.getElementsByClassName('leaflet-top leaflet-right').length) || (!executed)) {{
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.display = "flex"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].style.flexDirection = "column"
                                          document.getElementsByClassName('leaflet-top leaflet-right')[0].innerHTML += `{legend_html}`;
                                          clearInterval(checkExist);
                                          executed = true;
                                       }}
                                    }}, 100);
                        }}
                    }};
                }})();
        oneTimeExecution()
        </script>
      """
   

    css = """

    <style type='text/css'>
      .maplegend {
        z-index:9999;
        float:right;
        background-color: rgba(255, 255, 255, 1);
        border-radius: 5px;
        border: 2px solid #bbb;
        padding: 10px;
        font-size:12px;
        positon: relative;
      }
      .maplegend .legend-title {
        text-align: left;
        margin-bottom: 5px;
        font-weight: bold;
        font-size: 90%;
        }
      .maplegend .legend-scale ul {
        margin: 0;
        margin-bottom: 5px;
        padding: 0;
        float: left;
        list-style: none;
        }
      .maplegend .legend-scale ul li {
        font-size: 80%;
        list-style: none;
        margin-left: 0;
        line-height: 18px;
        margin-bottom: 2px;
        }
      .maplegend ul.legend-labels li span {
        display: block;
        float: left;
        height: 16px;
        width: 30px;
        margin-right: 5px;
        margin-left: 0;
        border: 0px solid #ccc;
        }
      .maplegend .legend-source {
        font-size: 80%;
        color: #777;
        clear: both;
        }
      .maplegend a {
        color: #777;
        }
    </style>
    """

    folium_map.get_root().header.add_child(folium.Element(script + css))

    return folium_map
NO2.head()
# Out:
#    OBJECTNUMMER    Code               Locatie Type_meetpunt Type_meting  \
# 0             1   IJB19         Ijsbaanpad 19   Achtergrond      Palmes
# 1             2  DECL40    de Clercqstraat 40        Straat      Palmes
# 2             3  SPD165  Spaarndammerdijk 165        Straat      Palmes
# 3             4   SPD53   Spaarndammerdijk 53        Straat      Palmes
# 4             5   SPD29   Spaarndammerdijk 29        Straat      Palmes
#
#   Meting_op_wettelijke_toetsafst  Afstand_tot_gevel_m  jaar_2020  jaar_2019  \
# 0                            NaN                  0.0          0       25.9
# 1                            Nee                  0.0          0       31.6
# 2                             Ja                  0.0          0       32.4
# 3                             Ja                  0.0          0       30.7
# 4                             Ja                  0.0          0       31.5
#
#    jaar_2018  jaar_2017  jaar_2016  jaar_2015  jaar_2014  jaar_2013  \
# ...

# %%
m = folium.Map(location=[52.0893191, 5.1101691], zoom_start=7)
folium.TileLayer('stamentoner').add_to(m)

for index, row in NO2.iterrows() :
    folium.CircleMarker(location=[row['LAT'], row['LNG']], radius=row['jaar_2019'],
    popup=row['Locatie'], line_color=color_producer(row['Type_meetpunt']),
    fill_color=color_producer(row['Type_meetpunt']), color= color_producer(row['Type_meetpunt']), fill_opacity=0.8).add_to(m)



m = add_categorical_legend(m, 'title',
                             colors = ['blue', 'red', 'purple', 'yellow', 'green'],
                           labels = ['Achtergrond', 'Straat', 'Snelweg', 'Waterweg', 'Meetstation'])



folium.TileLayer('stamentoner').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%20type%3D%22text/javascript%22%3E%0A%20%20%20%20%20%20%20%20var%20oneTimeExecution%20%3D%20%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20executed%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20return%20function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28%21executed%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2
# ...

# %% [markdown]
# Kopieer nu je bovenstaande code en vul aan:
#
# - De kleur van de rand en de opvulling van de cirkel is hetzelfde
# - De grootte van het meetpunt (straal) is evenredig met de waarde van de gemeten hoeveelheid stikstof.
# - Het jaar is te selecteren.

# %%
m = folium.Map(location=[52.0893191, 5.1101691], zoom_start=7)
folium.TileLayer('stamentoner').add_to(m)

for index, row in NO2.iterrows() :
    folium.CircleMarker(location=[row['LAT'], row['LNG']], radius=10,
    popup=row['Locatie'], line_color=color_producer(row['Type_meetpunt']),
    fill_color=color_producer(row['Type_meetpunt']), color= color_producer(row['Type_meetpunt']), fill_opacity=0.8).add_to(m)



m = add_categorical_legend(m, 'title',
                             colors = ['blue', 'red', 'purple', 'yellow', 'green'],
                           labels = ['Achtergrond', 'Straat', 'Snelweg', 'Waterweg', 'Meetstation'])


folium.TileLayer('stamentoner').add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%20type%3D%22text/javascript%22%3E%0A%20%20%20%20%20%20%20%20var%20oneTimeExecution%20%3D%20%28function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20executed%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20return%20function%28%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20if%20%28%21executed%29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2
# ...

# %% [markdown]
# ## Onderdeel 5

# %% [markdown]
# Beschrijf op basis van, en met onderbouwing door, de gemaakte afbeeldingen in onderdeel 4:
#
# - welke informatie de data weergeeft.
#
# De radius van de cirkel geeft weer hoeveel stikstof er per jaar rond de meetpunten werd uitgestoten.
# Daarnaast wordt er met de kleur van de cirkel aangegeven wat voor een locatie het is.

# %% [markdown]
# # Deel 3 - WHO data

# %% [markdown]
# De Wereldgezondheidsorganisatie publiceert veel data. Denk aan de leversverwachting, het BMI en het aantal doden op de weg. Kies een willekeurige dataset per land en zoek een geojson file met landen.

# %% [markdown]
# ## Onderdeel 6

# %% [markdown]
# Laad geopandas in. Geeft dit een error, volg dan de stappen aangegeven in de bijgevoegde slides.

# %%
# !pip install fiona
import geopandas as gpd
# Out:
# ...
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
# ...

# %%
# Gegeven code

countries = gpd.read_file('countries.geojson')
life_expectancy = pd.read_csv('Life_Expectancy_Data.csv')

print(countries.head())
print("--------------")
print(life_expectancy.head())

# %% [markdown]
# Laad de data van de WHO en de geojson file in en voeg deze samen.

# %%
countries = countries.rename(columns={'ADMIN': 'Country'})

merge_df = countries.merge(life_expectancy, on="Country")

print(merge_df)

# %% [markdown]
# ## Onderdeel 7

# %% [markdown]
# We gaan de data uit onderdeel 6 gebruiken om de landen een kleur te geven afhankelijk van de gekozen data van de WHO.
#
# Deel 1:
# Maak een kaart met de volgende eisen:
#
# - Zorg dat alle landen van de wereld direct volledig in beeld te zien zijn.
# - Geen (interactieve) zoom opties.
# - Een geschikte achtergrondskaart, expliciet gedefineerd.

# %%
# Hieronder jouw code voor deel 1
m = folium.Map(location=[52.0893191, 5.1101691], zoom_start=1, zoom_control=False,scrollWheelZoom=False,
               dragging=False)

folium.TileLayer('stamentoner').add_to(m)
m
#####Door deze tilelayer te kiezen zullen de landen goed zichtbaar zijn op de kaart. Dit komt de witte achtergrond.

# %% [markdown]
# Deel 2, vul de code van deel 1 aan:
#
# Gebruik `Choropleth` om deze afbeelding te maken met aanvullende eisen:
#
# - Baken de landen af met lijntjes in een expliciet gedefinieerde ondoorzichtigheid (opacity).
# - Stel de ondoorzichtigheid (opacity) van de opvulling expliciet in op een voor jou optimale waarde.
# - Defineer een geschikt kleurenpalet naar jouw keuze voor de vlakken.
# - Voeg een legenda toe (hier is al iets voor geschreven)

# %%
# Hieronder jouw code voor deel 2
m = folium.Map(location=[52.0893191, 5.1101691], zoom_start=1, zoom_control=False,scrollWheelZoom=False,
               dragging=False)


folium.Choropleth(
    geo_data=merge_df,
    line_opacity=0.8,
    fill_opacity=0.1,
    columns=['Country', 'Life expectancy']
).add_to(m)
m

# %% [markdown]
# m

# %%
  name="choropleth",
    data=life_expectancy,
    columns=["Country", "geometry"],
    line_opacity=0.2,
    key_on='feature.properties.country'

# %%
m = folium.Map()


## voeg code toe


# code voor de legenda
from branca.element import Template, MacroElement

template = """
{% macro html(this, kwargs) %}

<!doctype html>
<html lang="en">
<head>
  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <title>jQuery UI Draggable - Default functionality</title>
  <link rel="stylesheet" href="//code.jquery.com/ui/1.12.1/themes/base/jquery-ui.css">

  <script src="https://code.jquery.com/jquery-1.12.4.js"></script>
  <script src="https://code.jquery.com/ui/1.12.1/jquery-ui.js"></script>
  
  <script>
  $( function() {
    $( "#maplegend" ).draggable({
                    start: function (event, ui) {
                        $(this).css({
                            right: "auto",
                            top: "auto",
                            bottom: "auto"
                        });
                    }
                });
});

  </script>
</head>
<body>

 
<div id='maplegend' class='maplegend' 
    style='position: absolute; z-index:9999; border:2px solid grey; background-color:rgba(255, 255, 255, 0.8);
     border-radius:6px; padding: 10px; font-size:14px; right: 20px; bottom: 20px;'>
     
<div class='legend-title'>Legenda</div>
<div class='legend-scale'>
  <ul class='legend-labels'>
    <li><span style='background:black;opacity:0.7;'></span>N.B.</li>


  </ul>
</div>
</div>
 
</body>
</html>

<style type='text/css'>
  .maplegend .legend-title {
    text-align: left;
    margin-bottom: 5px;
    font-weight: bold;
    font-size: 90%;
    }
  .maplegend .legend-scale ul {
    margin: 0;
    margin-bottom: 5px;
    padding: 0;
    float: left;
    list-style: none;
    }
  .maplegend .legend-scale ul li {
    font-size: 80%;
    list-style: none;
    margin-left: 0;
    line-height: 18px;
    margin-bottom: 2px;
    }
  .maplegend ul.legend-labels li span {
    display: block;
    float: left;
    height: 16px;
    width: 30px;
    margin-right: 5px;
    margin-left: 0;
    border: 1px solid #999;
    }
  .maplegend .legend-source {
    font-size: 80%;
    color: #777;
    clear: both;
    }
  .maplegend a {
    color: #777;
    }
</style>
{% endmacro %}"""

macro = MacroElement()
macro._template = Template(template)

m.get_root().add_child(macro)

display(m)

# %% [markdown]
# # Deel 4: Overig

# %% [markdown]
# ## Onderdeel 8

# %% [markdown]
# Voor dit onderdeel gaan we even terug naar plotly en sliders / dropdowns.
# Gebruik een dataset zoals omschreven in: https://plotly.com/python/mapbox-county-choropleth/
# * Maak een plot met plotly van deze data met een kleurenschema.
# * Geef de plot een dropdown (bijvoorbeeld van welk kleurenschema) of een slider mee.
# * Je mag dus ook een ander soort plot maken als je wilt (bijvoorbeeld een bubble map). Hoeft niet, mag wel.

# %% [markdown]
# ## Onderdeel 9 (bonus)

# %% [markdown]
# Voor dit onderdeel mag je de data uit deel 2 of 3 gebruiken maar je mag ook andere data gebruiken of toevoegen.
#
# Er zijn nog veel meer functies in Folium die nog niet gebruikt zijn. Gebruik je creativiteit en laat zien dat jij Folium snapt. Gebruik drie functies die we nog niet eerder gezien hebben.
